# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including pandas, numpy, scikit-learn, mlflow, fastapi and others.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import mlflow

# data processing
import sklearn

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# API helper
from fastapi import FastAPI

# %% [markdown]
# # Load Data
# # Load RC.csv, PC.csv, and MOUVEMENT.csv into DataFrames, handling encoding, separators, data types, and date parsing.

# %%
rc = pd.read_csv(r"data/raw/RC.csv", parse_dates=["date_opened"], encoding="utf-8")
pc = pd.read_csv(r"data/raw/PC.csv", parse_dates=["opened_date"], encoding="utf-8")
mv = pd.read_csv(r"data/raw/MOUVEMENT.csv", parse_dates=["date"], encoding="utf-8")
rc.head(), pc.head(), mv.head()

# %% [markdown]
# # Validate Data
# # Validate data for required columns, duplicates, missing values, data types, and anomalies, generating a summary report.

# %%
from src.data.validate_data import validate_all

report = validate_all(rc, pc, mv)
report
